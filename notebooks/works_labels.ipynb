# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("test_pyspark") \
    .config("spark.driver.memory", "100g") \
    .config("spark.executor.memory", "100g") \
    .config("spark.sql.orc.enableVectorizedReader", "false") \
    .config("spark.sql.parquet.columnarReaderBatchSize", "256") \
    .config("spark.sql.orc.columnarReaderBatchSize", "256") \
    .config("spark.sql.shuffle.partitions", "1024") \
    .config("spark.driver.maxResultSize", "4g") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/07/03 13:25:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark.table("works").printSchema()
# Out:
# root
#  |-- alternativeTitles: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- availabilities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- contributors: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- agent: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- primary: boolean (nullable = true)
#  |    |    |-- roles: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- createdDate: struct (nullable = true)
#  |    |-- label: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- currentFrequency: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- designation: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- duration: long (nullable = true)
#  |-- edition: string (nullable = true)
#  |-- formerFrequency: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- concepts: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- holdings: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- enumeration: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- location: struct (nullable = true)
#  |    |    |    |-- accessConditions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- method: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- status: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- linkText: string (nullable = true)
#  |    |    |    |-- locationType: struct (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- shelfmark: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- note: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- identifiers: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- locations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- accessConditions: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- method: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- note: string (nullable = true)
#  |    |    |    |    |    |    |-- status: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- terms: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- credit: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- linkText: string (nullable = true)
#  |    |    |    |    |-- locationType: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- shelfmark: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- note: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- languages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- lettering: string (nullable = true)
#  |-- notes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- contents: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- noteType: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- partOf: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- partOf: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- parts: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- physicalDescription: string (nullable = true)
#  |-- precededBy: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- production: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- agents: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- dates: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- function: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- places: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- referenceNumber: string (nullable = true)
#  |-- subjects: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- concepts: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- succeededBy: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- thumbnail: struct (nullable = true)
#  |    |-- accessConditions: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- license: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- locationType: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- workType: struct (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- label: string (nullable = true)
#  |    |-- type: string (nullable = true)

# %%
# Explore the genres column
# First, let's see some sample data from the genres column
print("Sample genres data:")
spark.table("works").select("genres").show(10, truncate=False)
# Out:
# Sample genres data:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |genres                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[{[{kqkakf66, [{{label-derived, Identifier derived from the label of the referent, IdentifierType}, Identifier, electronic books}], Electronic books, Genre}], Electronic books, Genre}, {[{ajcm2jdg, [{{label-derived, Identifier derived from the label of the referent, IdentifierType}, Identifier, annual reports}], Annual reports, Genre}], Annual reports, Genre}, {[{hs84p4dk, [{{label-derived, Identifier derived from the label of the referent, IdentifierType}, Identifier, colonial reports}], Colonial reports, Genre}], Colonial reports, Genre}]|
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import explode, col

# Extract unique labels from the genres column
# The genres column appears to be an array of structs with 'label' field
print("Unique genre labels:")
unique_labels = spark.table("works") \
    .select(explode(col("genres")).alias("genre")) \
    .select("genre.label") \
    .distinct() \
    .orderBy("label")

unique_labels.show(100, truncate=False)

# Count the number of unique labels
label_count = unique_labels.count()
print(f"\nTotal number of unique genre labels: {label_count}")
# Out:
# Unique genre labels:
# +--------------------------------------------------------------------+
# |label                                                               |
# +--------------------------------------------------------------------+
# |AB.AH                                                               |
# |Abstract journals (form)                                            |
# |Abstracts                                                           |
# |Academic Dissertation                                               |
# |Academic Dissertations                                              |
# |Academic addresses                                                  |
# |Academic addresses - Netherlands - Leiden                           |
# |Academic catalogues                                                 |
# |Academic dissertations                                              |
# |Academic dissertations - Austria - Vienna                           |
# |Academic dissertations - Denmark - Copenhagen - 18th cent           |
# |Academic dissertations - England - Cambridge - 18th cent            |
# |Academic dissertations - France - 17th cent                         |
# |Academic dissertations - France - 19th cent                         |
# |Academic dissertations - France - Montpellier                       |
# |Academic dissertations - France - Montpellier - 18th cent           |
# |Academic dissertations - France - Paris                             |
# |Academic dissertations - France - Paris - 18th cent                 |
# |Academic dissertations - France - Paris - 19th cent                 |
# |Academic dissertations - France - Strasbourg - 17th cent            |
# |Academic dissertations - France - Strasbourg - 18th cent            |
# |Academic dissertations - Germany - 18th cent                        |
# |Academic dissertations - Germany - Altdorf - 17th cent              |
# |Academic dissertations - Germany - Altdorf - 18th cent              |
# |Academic dissertations - Germany - Berlin                           |
# |Academic dissertations - Germany - Erfurt                           |
# |Academic dissertations - Germany - Erfurt - 17th cent               |
# |Academic dissertations - Germany - Erfurt - 18th cent               |
# |Academic dissertations - Germany - Erlangen                         |
# |Academic dissertations - Germany - Erlangen - 18th cent             |
# |Academic dissertations - Germany - Frankfurt am Main                |
# |Academic dissertations - Germany - Frankfurt an der Oder - 18th cent|
# |Academic dissertations - Germany - Giessen - 17th cent              |
# |Academic dissertations - Germany - Giessen - 18th cent              |
# |Academic dissertations - Germany - Greifswald - 17th cent           |
# |Academic dissertations - Germany - Göttingen                        |
# |Academic dissertations - Germany - Göttingen - 18th cent            |
# |Academic dissertations - Germany - Halle - 17th cent                |
# |Academic dissertations - Germany - Halle - 18th cent                |
# |Academic dissertations - Germany - Heidelberg - 17th cent           |
# |Academic dissertations - Germany - Heidelberg - 18th cent           |
# |Academic dissertations - Germany - Helmstedt - 17th cent            |
# |Academic dissertations - Germany - Jena - 17th cent                 |
# |Academic dissertations - Germany - Jena - 18th cent                 |
# |Academic dissertations - Germany - Kiel                             |
# |Academic dissertations - Germany - Königsberg - 18th cent           |
# |Academic dissertations - Germany - Leipzig                          |
# |Academic dissertations - Germany - Leipzig - 17th cent              |
# |Academic dissertations - Germany - Leipzig - 18th cent              |
# |Academic dissertations - Germany - Leipzig - 19th cent              |
# |Academic dissertations - Germany - Tübingen - 16th cent             |
# |Academic dissertations - Germany - Tübingen - 17th cent             |
# |Academic dissertations - Germany - Tübingen - 18th cent             |
# |Academic dissertations - Germany - Tübingen - 19th cent             |
# |Academic dissertations - Germany - Wittenberg - 17th cent           |
# |Academic dissertations - Germany - Wittenberg - 18th cent           |
# |Academic dissertations - Leyden - 17th cent                         |
# |Academic dissertations - Netherlands - Amsterdam - 19th cent        |
# |Academic dissertations - Netherlands - Franeker - 18th cent         |
# |Academic dissertations - Netherlands - Leiden                       |
# |Academic dissertations - Netherlands - Leiden - 17th cent           |
# |Academic dissertations - Netherlands - Leiden - 18th cent           |
# |Academic dissertations - Netherlands - Leyden - 17th cent           |
# |Academic dissertations - Netherlands - Utrecht - 18th cent          |
# |Academic dissertations - Netherlands - Utrecht - 19th cent          |
# |Academic dissertations - Pennsylvania - 19th cent                   |
# |Academic dissertations - Scotland - Edinburgh                       |
# |Academic dissertations - Scotland - Edinburgh - 18th cent           |
# |Academic dissertations - Scotland - Edinburgh - 19th cent           |
# |Academic dissertations - Scotland - Glasgow                         |
# |Academic dissertations - Scotland - Glasgow - 18th cent             |
# |Academic dissertations - Sweden - 18th cent                         |
# |Academic dissertations - Sweden - Uppsala                           |
# |Academic dissertations - Sweden - Uppsala - 18th cent               |
# |Academic dissertations - Switzerland - Basel - 17th cent            |
# |Academic dissertations - Switzerland - Basel - 18th cent            |
# |Academic theses                                                     |
# |Academic/Scholarly publication                                      |
# |Acadmic dissertations                                               |
# |Account books                                                       |
# |Acrostics                                                           |
# |Acrylic paintings                                                   |
# |Actes de congrès                                                   |
# |Activity books                                                      |
# |Adaptations                                                         |
# |Addresses                                                           |
# |Advertisements                                                      |
# |Advertisements - Canada - 20th century                              |
# |Advertisements - Hardware                                           |
# |Advertisements - United States - 20th century                       |
# |Advertising                                                         |
# |Advertising cards                                                   |
# |Advertising fliers - England - 17th century                         |
# |Advertising fliers - England - London - 17th century                |
# |Advertising fliers - England - London - 17th-18th century           |
# |Advertising fliers - England - London - 18th century                |
# |Advertising fliers - England - York - 19th century                  |
# |Advertising t-shirts                                                |
# |Aerial views                                                        |
# |Airbrush works                                                      |
# +--------------------------------------------------------------------+
# only showing top 100 rows
#
#
# Total number of unique genre labels: 1523
#
# Total number of unique genre labels: 1523

# %%
# Show frequency of each genre label
print("Genre label frequencies (top 50):")
label_frequencies = spark.table("works") \
    .select(explode(col("genres")).alias("genre")) \
    .select("genre.label") \
    .groupBy("label") \
    .count() \
    .orderBy(col("count").desc())

label_frequencies.show(50, truncate=False)

print(f"\nTotal number of genre label occurrences: {label_frequencies.agg({'count': 'sum'}).collect()[0][0]}")
# Out:
# Genre label frequencies (top 50):
# +----------------------+------+
# |label                 |count |
# +----------------------+------+
# |Electronic books      |191342|
# |Annual reports        |82239 |
# |MOH reports           |71897 |
# |Pamphlets             |37280 |
# |Statistics            |23553 |
# |Ephemera              |20110 |
# |Academic dissertations|16479 |
# |Engravings            |14165 |
# |Lithographs           |12570 |
# |Periodicals           |11403 |
# |Etchings              |9914  |
# |Portrait prints       |9756  |
# |Photographs           |9675  |
# |Conference proceedings|8006  |
# |Posters               |6469  |
# |Photographic prints   |6034  |
# |Leaflets              |5933  |
# |Biographies           |5850  |
# |Paintings             |5806  |
# |Advertising cards     |3928  |
# |Videocassettes        |3772  |
# |Obituaries            |3515  |
# |Watercolors           |3472  |
# |Portrait photographs  |3429  |
# |Colonial reports      |3322  |
# |Hospital reports      |3315  |
# |Quick Ref. Collection |2930  |
# |Drawings              |2908  |
# |Prints                |2882  |
# |Wood engravings       |2804  |
# |Patents               |2541  |
# |DVDs                  |2440  |
# |Manuscripts - Sanskrit|2430  |
# |Stipple engravings    |2414  |
# |Gouaches              |2126  |
# |Intaglio prints       |2098  |
# |Caricatures           |2081  |
# |Book illustrations    |2069  |
# |Motion pictures       |2065  |
# |Student Collection    |2021  |
# |Zines                 |1967  |
# |Broadsides            |1946  |
# |Advertisements        |1943  |
# |Sound recordings      |1897  |
# |Bibliographies        |1841  |
# |Photomechanical prints|1750  |
# |Labels                |1707  |
# |Archives              |1702  |
# |Essays                |1574  |
# |Electronic journals   |1569  |
# +----------------------+------+
# only showing top 50 rows
#
#
# Total number of genre label occurrences: 708658

# %%
# Explore the subjects column
# First, let's see some sample data from the subjects column
print("Sample subjects data:")
spark.table("works").select("subjects").show(10, truncate=False)
# Out:
# Sample subjects data:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |subjects                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[{[{qsazb8t4, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D006298}], Health Services Administration, Concept}], qsazb8t4, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D006298}], Health Services Administration, Subject}, {[{z2eup69w, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D011635}], Public Health Administration, Concept}], z2eup69w, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D011635}], Public Health Administration, Subject}, {[{eva7r2dw, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D012499}], Sanitation, Concept}], eva7r2dw, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D012499}], Sanitation, Subject}, {[{r7nafdhx, [{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n79100617}], South Australia, Place}], r7nafdhx, [{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n79100617}], South Australia, Subject}]|
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |[{[{yfvkdrf2, [{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n80126261}], International Union against Cancer, Organisation}], yfvkdrf2, [{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n80126261}], International Union against Cancer, Subject}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
# Extract unique labels from the subjects column
# The subjects column appears to be an array of structs with 'label' field
print("Unique subject labels:")
unique_subject_labels = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select("subject.label") \
    .distinct() \
    .orderBy("label")

unique_subject_labels.show(100, truncate=False)

# Count the number of unique subject labels
subject_label_count = unique_subject_labels.count()
print(f"\nTotal number of unique subject labels: {subject_label_count}")
# Out:
# Unique subject labels:
# +---------------------------------------------------------------+
# |label                                                          |
# +---------------------------------------------------------------+
# |!Kung (African people)                                         |
# |"Degewop" Gesellschaft wissenschaftlicher Organpräparate (Firm)|
# |"Erma" di Bretschneider                                        |
# |"Not Forgotten" Association                                    |
# |"St. Ronan's Wells" & Mineral Water Company                    |
# |"Stud" Company (Manchester) Ltd                                |
# |"Thread-horned" flies                                          |
# |"Vita" Glass Marketing Board                                   |
# |#                                                              |
# |#UTATION                                                       |
# |'AT HOME'                                                      |
# |'Alī ibn Sahl Rabbān, al-Ṭabarī. Firdaws al-ḥikmah.            |
# |'Eua Island (Tonga)                                            |
# |'Powder of Sympathy'                                           |
# |'Solago Minor'                                                 |
# |'s-Hertogenbosch (Netherlands)                                 |
# |(1515?-1559)                                                   |
# |(GAB REF. 326586)                                              |
# |(GAB REF. IV-014 N.13)                                         |
# |(Our Lady Fair)                                                |
# |)                                                              |
# |, attributed to Rembrandt Books and reading                    |
# |-                                                              |
# |-1564.                                                         |
# |-1804. Streit der Fakultäten. Italian.                         |
# |-1865.                                                         |
# |-1874.                                                         |
# |-1880.                                                         |
# |-1994.                                                         |
# |-1996.                                                         |
# |-1999.                                                         |
# |-2001.                                                         |
# |-2003.                                                         |
# |-2004.                                                         |
# |-ca. 1564.                                                     |
# |05.                                                            |
# |1-1788 (comte de)                                              |
# |1-Propanol - pharmacology                                      |
# |10th century                                                   |
# |10th-11th centuries                                            |
# |10th-12th centuries                                            |
# |10th-13th centuries                                            |
# |10th-17th centuries                                            |
# |10th-20th centuries                                            |
# |11th century                                                   |
# |11th-12th centuries                                            |
# |11th-13th centuries                                            |
# |11th-14th centuries                                            |
# |11th-15th centuries                                            |
# |11th-16th centuries                                            |
# |11th-17th centuries                                            |
# |11th-20th centuries                                            |
# |12th century                                                   |
# |12th-13th centuries                                            |
# |12th-14th centuries                                            |
# |12th-15th centuries                                            |
# |12th-16th centuries                                            |
# |12th-17th centuries                                            |
# |12th-18th centuries                                            |
# |12th-19th centuries                                            |
# |13. Bezirk (Vienna, Austria)                                   |
# |1391-1461                                                      |
# |13th century                                                   |
# |13th-14th centuries                                            |
# |13th-15th centuries                                            |
# |13th-16th centuries                                            |
# |13th-17th centuries                                            |
# |13th-18th centuries                                            |
# |13th-19th centuries                                            |
# |13th-20th centuries                                            |
# |13th-21st centuries                                            |
# |1495                                                           |
# |14th -17th centuries                                           |
# |14th century                                                   |
# |14th-15th centuries                                            |
# |14th-16th centuries                                            |
# |14th-16th centuries,                                           |
# |14th-17th centuries                                            |
# |14th-18th centuries                                            |
# |14th-19th centuries                                            |
# |14th-20th centuries                                            |
# |14th-21st centuries                                            |
# |15-17th centuries                                              |
# |1500-1577                                                      |
# |1500-1600                                                      |
# |1523                                                           |
# |1550                                                           |
# |1552-1902                                                      |
# |1578-1625                                                      |
# |1580-1656                                                      |
# |15TH CENTURY                                                   |
# |15th - 18th centuries                                          |
# |15th Century                                                   |
# |15th century                                                   |
# |15th-16th centuries                                            |
# |15th-17th centuries                                            |
# |15th-18th centuries                                            |
# |15th-19th centuries                                            |
# |15th-20th centuries                                            |
# |1628-1694                                                      |
# +---------------------------------------------------------------+
# only showing top 100 rows
#
#
# Total number of unique subject labels: 204322

# %%
# Show frequency of each subject label
print("Subject label frequencies (top 50):")
subject_label_frequencies = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select("subject.label") \
    .groupBy("label") \
    .count() \
    .orderBy(col("count").desc())

subject_label_frequencies.show(50, truncate=False)

print(f"\nTotal number of subject label occurrences: {subject_label_frequencies.agg({'count': 'sum'}).collect()[0][0]}")
# Out:
# Subject label frequencies (top 50):
# +-------------------------------+-----+
# |label                          |count|
# +-------------------------------+-----+
# |Sanitation                     |66922|
# |Public Health                  |66007|
# |Water Supply                   |63415|
# |Disease Outbreaks              |63156|
# |Great Britain                  |20033|
# |London (England)               |10386|
# |20th century                   |8498 |
# |United States                  |8372 |
# |Medicine                       |6852 |
# |19th century                   |6300 |
# |Physicians                     |5890 |
# |Hospitals                      |4709 |
# |Germany                        |4650 |
# |Ophthalmology                  |4402 |
# |England                        |4278 |
# |Medicine - History             |4159 |
# |Sex                            |4038 |
# |France                         |3973 |
# |19th-20th centuries            |3839 |
# |Ancient                        |3819 |
# |Science                        |3598 |
# |India                          |3554 |
# |Public Health Administration   |3424 |
# |18th century                   |3403 |
# |School Health Services         |3356 |
# |Pharmaceutical Preparations    |3321 |
# |Anatomy                        |3315 |
# |Health Services Administration |3235 |
# |AIDS (Disease)                 |3206 |
# |Prostitution                   |3136 |
# |Prostitutes                    |3110 |
# |Hospitals, Psychiatric         |3101 |
# |Physiology                     |3072 |
# |Medieval                       |2999 |
# |Research                       |2929 |
# |Women                          |2911 |
# |Drug Industry                  |2881 |
# |General Surgery                |2615 |
# |Europe                         |2532 |
# |Drugs                          |2529 |
# |Astrology - Early works to 1800|2431 |
# |Science - history              |2407 |
# |Human anatomy                  |2369 |
# |Hygiene                        |2308 |
# |Cooking                        |2167 |
# |Obstetrics                     |2124 |
# |Eye                            |2116 |
# |Hospitals - history            |2088 |
# |17th century                   |2080 |
# |Botany                         |2037 |
# +-------------------------------+-----+
# only showing top 50 rows
#
#
# Total number of subject label occurrences: 1865430

# %%
# Survey concept types in the subjects column
# First, let's see what fields are available in the subjects structure
print("Sample subjects data with all fields:")
spark.table("works").select("subjects").show(5, truncate=False)

# Let's also look at the schema of the subjects column
print("\nSubjects column schema:")
subjects_schema = spark.table("works").select("subjects").schema
print(subjects_schema)
# Out:
# Sample subjects data with all fields:
# +--------+
# |subjects|
# +--------+
# |[]      |
# |[]      |
# |[]      |
# |[]      |
# |[]      |
# +--------+
# only showing top 5 rows
#
#
# Subjects column schema:
# StructType([StructField('subjects', ArrayType(StructType([StructField('concepts', ArrayType(StructType([StructField('id', StringType(), True), StructField('identifiers', ArrayType(StructType([StructField('identifierType', StructType([StructField('id', StringType(), True), StructField('label', StringType(), True), StructField('type', StringType(), True)]), True), StructField('type', StringType(), True), StructField('value', StringType(), True)]), True), True), StructField('label', StringType(), True), StructField('type', StringType(), True)]), True), True), StructField('id', StringType(), True), StructField('identifiers', ArrayType(StructType([StructField('identifierType', StructType([StructField('id', StringType(), True), StructField('label', StringType(), True), StructField('type', StringType(), True)]), True), StructField('type', StringType(), True), StructField('value', StringType(), True)]), True), True), StructField('label', StringType(), True), StructField('type', StringType(), True)]), True), True)])

# %%
# Extract unique concept types from the subjects column
# The subjects column contains structs with 'concepts' field that has concept types
print("Unique concept types in subjects:")
concept_types = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(explode(col("subject.concepts")).alias("concept")) \
    .select("concept.type") \
    .distinct() \
    .orderBy("type")

concept_types.show(100, truncate=False)

# Count the number of unique concept types
concept_type_count = concept_types.count()
print(f"\nTotal number of unique concept types: {concept_type_count}")
# Out:
# Unique concept types in subjects:
# +------------+
# |type        |
# +------------+
# |Concept     |
# |Meeting     |
# |Organisation|
# |Period      |
# |Person      |
# |Place       |
# +------------+
#
#
# Total number of unique concept types: 6

# %%
# Show frequency of each concept type
print("Concept type frequencies:")
concept_type_frequencies = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(explode(col("subject.concepts")).alias("concept")) \
    .select("concept.type") \
    .groupBy("type") \
    .count() \
    .orderBy(col("count").desc())

concept_type_frequencies.show(truncate=False)

print(f"\nTotal number of concept type occurrences: {concept_type_frequencies.agg({'count': 'sum'}).collect()[0][0]}")
# Out:
# Concept type frequencies:
# +------------+-------+
# |type        |count  |
# +------------+-------+
# |Concept     |1765932|
# |Place       |272764 |
# |Person      |103407 |
# |Period      |59629  |
# |Organisation|46018  |
# |Meeting     |705    |
# +------------+-------+
#
#
# Total number of concept type occurrences: 2248455

# %%
# Explore identifierType.label in the subjects column
# Let's first check what's in the identifiers field within subjects
print("Sample identifiers data from subjects:")
spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select("subject.identifiers") \
    .show(10, truncate=False)

# Extract unique identifierType labels from the identifiers field
print("\nUnique identifierType labels in subjects:")
identifier_type_labels = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(explode(col("subject.identifiers")).alias("identifier")) \
    .select("identifier.identifierType.label") \
    .distinct() \
    .orderBy("label")

identifier_type_labels.show(100, truncate=False)

# Count the number of unique identifierType labels
identifier_type_count = identifier_type_labels.count()
print(f"\nTotal number of unique identifierType labels: {identifier_type_count}")
# Out:
# Sample identifiers data from subjects:
# +-------------------------------------------------------------------------------------------------+
# |identifiers                                                                                      |
# +-------------------------------------------------------------------------------------------------+
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D006298}]  |
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D011635}]  |
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D012499}]  |
# |[{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n79100617}]|
# |[{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n80126261}]|
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D006973}]  |
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D004196}]  |
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D011634}]  |
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D012499}]  |
# |[{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D014881}]  |
# +-------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
#
# Unique identifierType labels in subjects:
# +-------------------------------------------------+
# |label                                            |
# +-------------------------------------------------+
# |Identifier derived from the label of the referent|
# |Library of Congress Name authority records       |
# |Library of Congress Subject Headings (LCSH)      |
# |Medical Subject Headings (MeSH) identifier       |
# +-------------------------------------------------+
#
#
# Total number of unique identifierType labels: 4

# %%
# Show frequency of each identifierType label
print("IdentifierType label frequencies:")
identifier_type_frequencies = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(explode(col("subject.identifiers")).alias("identifier")) \
    .select("identifier.identifierType.label") \
    .groupBy("label") \
    .count() \
    .orderBy(col("count").desc())

identifier_type_frequencies.show(truncate=False)

print(f"\nTotal number of identifierType label occurrences: {identifier_type_frequencies.agg({'count': 'sum'}).collect()[0][0]}")
# Out:
# IdentifierType label frequencies:
# +-------------------------------------------------+------+
# |label                                            |count |
# +-------------------------------------------------+------+
# |Medical Subject Headings (MeSH) identifier       |811002|
# |Library of Congress Subject Headings (LCSH)      |449876|
# |Identifier derived from the label of the referent|330754|
# |Library of Congress Name authority records       |273785|
# +-------------------------------------------------+------+
#
#
# Total number of identifierType label occurrences: 1865417

# %%
# Explore concepts.label in the subjects column
print("Sample concepts data from subjects:")
spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select("subject.concepts") \
    .show(10, truncate=False)

# Extract unique concept labels from the concepts field
print("\nUnique concept labels in subjects:")
concept_labels = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(explode(col("subject.concepts")).alias("concept")) \
    .select("concept.label") \
    .distinct() \
    .orderBy("label")

concept_labels.show(100, truncate=False)

# Count the number of unique concept labels
concept_label_count = concept_labels.count()
print(f"\nTotal number of unique concept labels: {concept_label_count}")
# Out:
# Sample concepts data from subjects:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |concepts                                                                                                                                                         |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{qsazb8t4, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D006298}], Health Services Administration, Concept}]           |
# |[{z2eup69w, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D011635}], Public Health Administration, Concept}]             |
# |[{eva7r2dw, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D012499}], Sanitation, Concept}]                               |
# |[{r7nafdhx, [{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n79100617}], South Australia, Place}]                          |
# |[{yfvkdrf2, [{{lc-names, Library of Congress Name authority records, IdentifierType}, Identifier, n80126261}], International Union against Cancer, Organisation}]|
# |[{pt4vb2ez, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D006973}], Hypertension, Concept}]                             |
# |[{d6jhgxuc, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D004196}], Disease Outbreaks, Concept}]                        |
# |[{uj4hz4ct, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D011634}], Public Health, Concept}]                            |
# |[{eva7r2dw, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D012499}], Sanitation, Concept}]                               |
# |[{gtf5s7h7, [{{nlm-mesh, Medical Subject Headings (MeSH) identifier, IdentifierType}, Identifier, D014881}], Water Supply, Concept}]                             |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
#
# Unique concept labels in subjects:
# +---------------------------------------------------------------+
# |label                                                          |
# +---------------------------------------------------------------+
# |!Kung (African people)                                         |
# |"Degewop" Gesellschaft wissenschaftlicher Organpräparate (Firm)|
# |"Erma" di Bretschneider                                        |
# |"Not Forgotten" Association                                    |
# |"St. Ronan's Wells" & Mineral Water Company                    |
# |"Stud" Company (Manchester) Ltd                                |
# |"Thread-horned" flies                                          |
# |"Vita" Glass Marketing Board                                   |
# |#                                                              |
# |#UTATION                                                       |
# |'AT HOME'                                                      |
# |'Alī ibn Sahl Rabbān, al-Ṭabarī. Firdaws al-ḥikmah.            |
# |'Eua Island (Tonga)                                            |
# |'Powder of Sympathy'                                           |
# |'Solago Minor'                                                 |
# |'s-Hertogenbosch (Netherlands)                                 |
# |(1515?-1559)                                                   |
# |(GAB REF. 326586)                                              |
# |(GAB REF. IV-014 N.13)                                         |
# |(Our Lady Fair)                                                |
# |)                                                              |
# |, attributed to Rembrandt Books and reading                    |
# |, manuals etc                                                  |
# |-                                                              |
# |-1564.                                                         |
# |-1804. Streit der Fakultäten. Italian.                         |
# |-1865.                                                         |
# |-1874.                                                         |
# |-1880.                                                         |
# |-1994.                                                         |
# |-1996.                                                         |
# |-1999.                                                         |
# |-2001.                                                         |
# |-2003.                                                         |
# |-2004.                                                         |
# |-ca. 1564.                                                     |
# |05.                                                            |
# |1-1788                                                         |
# |1-Propanol                                                     |
# |1000-1526                                                      |
# |1040-1600                                                      |
# |1063-1284                                                      |
# |1066-1485                                                      |
# |1081-1453                                                      |
# |10th century                                                   |
# |10th-11th centuries                                            |
# |10th-12th centuries                                            |
# |10th-13th centuries                                            |
# |10th-17th centuries                                            |
# |10th-20th centuries                                            |
# |1138-1273                                                      |
# |1154-1399                                                      |
# |1185-1333                                                      |
# |1185-1600                                                      |
# |11th century                                                   |
# |11th-12th centuries                                            |
# |11th-13th centuries                                            |
# |11th-14th centuries                                            |
# |11th-15th centuries                                            |
# |11th-16th centuries                                            |
# |11th-17th centuries                                            |
# |11th-20th centuries                                            |
# |1258-1517                                                      |
# |1268-1492                                                      |
# |1268-1559                                                      |
# |1288-1918                                                      |
# |12th century                                                   |
# |12th-13th centuries                                            |
# |12th-14th centuries                                            |
# |12th-15th centuries                                            |
# |12th-16th centuries                                            |
# |12th-17th centuries                                            |
# |12th-18th centuries                                            |
# |12th-19th centuries                                            |
# |13. Bezirk (Vienna, Austria)                                   |
# |1328-1589                                                      |
# |1328-1600                                                      |
# |1333                                                           |
# |1337                                                           |
# |1377-1399                                                      |
# |1378-1447                                                      |
# |1391-1461                                                      |
# |1392-1910                                                      |
# |1397-1523                                                      |
# |13th century                                                   |
# |13th-14th centuries                                            |
# |13th-15th centuries                                            |
# |13th-16th centuries                                            |
# |13th-17th centuries                                            |
# |13th-18th centuries                                            |
# |13th-19th centuries                                            |
# |13th-20th centuries                                            |
# |13th-21st centuries                                            |
# |1420-1798                                                      |
# |1421-1737                                                      |
# |1434-1737                                                      |
# |1447-1565                                                      |
# |1450-1600                                                      |
# |1450-1800                                                      |
# |1453-1683                                                      |
# +---------------------------------------------------------------+
# only showing top 100 rows
#
#
# Total number of unique concept labels: 126714

# %%
# Show frequency of each concept label (top 50)
print("Concept label frequencies (top 50):")
concept_label_frequencies = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(explode(col("subject.concepts")).alias("concept")) \
    .select("concept.label") \
    .groupBy("label") \
    .count() \
    .orderBy(col("count").desc())

concept_label_frequencies.show(50, truncate=False)

print(f"\nTotal number of concept label occurrences: {concept_label_frequencies.agg({'count': 'sum'}).collect()[0][0]}")
# Out:
# Concept label frequencies (top 50):
# +----------------------------+-----+
# |label                       |count|
# +----------------------------+-----+
# |history                     |72789|
# |Public Health               |67797|
# |Sanitation                  |67289|
# |Disease Outbreaks           |63900|
# |Water Supply                |63539|
# |History                     |46476|
# |Great Britain               |28001|
# |Medicine                    |19286|
# |Early works to 1800         |15904|
# |United States               |13951|
# |19th century                |12275|
# |20th century                |12257|
# |England                     |11720|
# |Science                     |10536|
# |London (England)            |10467|
# |Physicians                  |8400 |
# |prevention & control        |8350 |
# |Hospitals                   |7963 |
# |drug therapy                |6291 |
# |therapy                     |6250 |
# |18th century                |6085 |
# |Women                       |6078 |
# |Germany                     |6002 |
# |France                      |5915 |
# |Research                    |5724 |
# |Botany                      |5519 |
# |Periodicals                 |5386 |
# |Diseases                    |5358 |
# |India                       |5324 |
# |AIDS (Disease)              |5274 |
# |Anatomy                     |4900 |
# |Ophthalmology               |4829 |
# |Sex                         |4646 |
# |Philosophy                  |4598 |
# |therapeutic use             |4534 |
# |Physiology                  |3884 |
# |General Surgery             |3848 |
# |19th-20th centuries         |3839 |
# |Hospitals, Psychiatric      |3833 |
# |Ancient                     |3820 |
# |Neoplasms                   |3759 |
# |Eye                         |3750 |
# |17th century                |3699 |
# |Pharmaceutical Preparations |3655 |
# |Public Health Administration|3592 |
# |Europe                      |3457 |
# |School Health Services      |3385 |
# |Psychology                  |3312 |
# |Italy                       |3287 |
# |Astrology                   |3282 |
# +----------------------------+-----+
# only showing top 50 rows
#
#
# Total number of concept label occurrences: 2248455

# %%
# Export unique concept labels with their IDs, identifierType, and concept type to CSV
print("Extracting unique concept labels with IDs, identifierType, and concept type...")
concept_labels_with_details = spark.table("works") \
    .select(explode(col("subjects")).alias("subject")) \
    .select(
        explode(col("subject.concepts")).alias("concept"),
        explode(col("subject.identifiers")).alias("identifier"),
        col("subject.label").alias("subject_label")
    ) \
    .select(
        "concept.id", 
        "concept.label", 
        "concept.type",
        "identifier.identifierType.label",
        "subject_label"
    ) \
    .distinct() \
    .orderBy("concept.label")

# Show sample data
print("Sample concept labels with details:")
concept_labels_with_details.show(20, truncate=False)

# Count total unique concept labels with details
total_unique_concepts = concept_labels_with_details.count()
print(f"\nTotal unique concept labels with details: {total_unique_concepts}")

# Export to CSV
output_path = "../data/tmp/unique_concept_labels_with_details.csv"
print(f"\nExporting to: {output_path}")

concept_labels_with_details.toPandas().to_csv(output_path, index=False)

print("Export completed successfully!")
# Out:
# Extracting unique concept labels with IDs, identifierType, and concept type...
# Sample concept labels with details:
# +--------+---------------------------------------------------------------+------------+-------------------------------------------------+---------------------------------------------------------------+
# |id      |label                                                          |type        |label                                            |subject_label                                                  |
# +--------+---------------------------------------------------------------+------------+-------------------------------------------------+---------------------------------------------------------------+
# |yrxf2hsf|!Kung (African people)                                         |Concept     |Library of Congress Subject Headings (LCSH)      |!Kung (African people)                                         |
# |f67f2qvs|"Degewop" Gesellschaft wissenschaftlicher Organpräparate (Firm)|Organisation|Identifier derived from the label of the referent|"Degewop" Gesellschaft wissenschaftlicher Organpräparate (Firm)|
# |qjtsdbr7|"Erma" di Bretschneider                                        |Organisation|Library of Congress Name authority records       |"Erma" di Bretschneider                                        |
# |smpc6zct|"Not Forgotten" Association                                    |Organisation|Identifier derived from the label of the referent|"Not Forgotten" Association                                    |
# |hp96592v|"St. Ronan's Wells" & Mineral Water Company                    |Organisation|Identifier derived from the label of the referent|"St. Ronan's Wells" & Mineral Water Company                    |
# |kgrznfus|"Stud" Company (Manchester) Ltd                                |Organisation|Identifier derived from the label of the referent|"Stud" Company (Manchester) Ltd                                |
# |d2mzzv24|"Thread-horned" flies                                          |Concept     |Identifier derived from the label of the referent|"Thread-horned" flies                                          |
# |t4hd79xn|"Vita" Glass Marketing Board                                   |Organisation|Identifier derived from the label of the referent|"Vita" Glass Marketing Board                                   |
# |z79y788s|#                                                              |Concept     |Identifier derived from the label of the referent|#                                                              |
# |rav2wzyw|#UTATION                                                       |Concept     |Identifier derived from the label of the referent|#UTATION                                                       |
# |phb3yb2d|'AT HOME'                                                      |Concept     |Identifier derived from the label of the referent|'AT HOME'                                                      |
# |bf5tjvse|'Alī ibn Sahl Rabbān, al-Ṭabarī. Firdaws al-ḥikmah.            |Person      |Identifier derived from the label of the referent|'Alī ibn Sahl Rabbān, al-Ṭabarī. Firdaws al-ḥikmah.            |
# |g5agtjwm|'Eua Island (Tonga)                                            |Place       |Library of Congress Subject Headings (LCSH)      |'Eua Island (Tonga)                                            |
# |bqd5ann6|'Powder of Sympathy'                                           |Concept     |Identifier derived from the label of the referent|'Powder of Sympathy'                                           |
# |p8wfhuus|'Solago Minor'                                                 |Concept     |Identifier derived from the label of the referent|'Solago Minor'                                                 |
# |c67sk5sx|'s-Hertogenbosch (Netherlands)                                 |Place       |Library of Congress Name authority records       |'s-Hertogenbosch (Netherlands)                                 |
# |tvj6scs7|(1515?-1559)                                                   |Concept     |Identifier derived from the label of the referent|(1515?-1559)                                                   |
# |b2pkab5k|(GAB REF. 326586)                                              |Concept     |Identifier derived from the label of the referent|(GAB REF. 326586)                                              |
# |pnrutbvy|(GAB REF. IV-014 N.13)                                         |Concept     |Identifier derived from the label of the referent|(GAB REF. IV-014 N.13)                                         |
# |c8axpva8|(Our Lady Fair)                                                |Meeting     |Identifier derived from the label of the referent|(Our Lady Fair)                                                |
# +--------+---------------------------------------------------------------+------------+-------------------------------------------------+---------------------------------------------------------------+
# only showing top 20 rows
# Total unique concept labels with details: 354910
#
# Exporting to: ../data/tmp/unique_concept_labels_with_details.csv
# Export completed successfully!
